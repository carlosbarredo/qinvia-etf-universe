# %% [markdown]
# <style>
# :root{--navy:#08296b;--blue:#0868d7;--cyan:#0bb9df;--ice:#eef7ff;--ink:#10213d;--muted:#62728a;--line:#dce8f4;--good:#0a9b71;--bad:#d84b5b;--amber:#d89014;--paper:#fff;color-scheme:light only}
# *{box-sizing:border-box}html{scroll-behavior:smooth}body{margin:0;font:15px/1.58 Inter,Segoe UI,Arial,sans-serif;color:var(--ink);background:#f3f7fb}header.qinvia-cover{width:min(1132px,calc(100% - 48px));margin:28px auto 0;padding:42px 30px 46px;background:linear-gradient(120deg,#f8fbff 0%,#eef6ff 55%,#e7faff 100%);border:1px solid #e3eaf3;border-radius:18px;box-shadow:0 18px 50px rgba(8,41,107,.09);position:relative;overflow:hidden}.qinvia-cover:after{content:'';position:absolute;right:-80px;bottom:-130px;width:360px;height:360px;border-radius:50%;background:radial-gradient(circle,rgba(11,185,223,.18),rgba(8,104,215,0) 68%);pointer-events:none}.qinvia-cover>a{display:inline-block;position:relative;z-index:1}.qinvia-logo{display:block;width:min(590px,78%);height:auto;margin:0 0 30px}.qinvia-eyebrow{position:relative;z-index:1;font-weight:800;letter-spacing:.16em;color:#0b72c9;font-size:.78rem}.qinvia-cover h1{position:relative;z-index:1;font-size:clamp(38px,5vw,58px);line-height:1.06;margin:.6rem 0 .7rem;color:var(--navy);max-width:980px;letter-spacing:-.035em}.qinvia-subtitle{position:relative;z-index:1;font-size:1.18rem;color:#3b587d;margin:0 0 1.4rem;max-width:980px}.qinvia-meta{position:relative;z-index:1;display:flex;gap:9px;flex-wrap:wrap}.qinvia-meta span{background:#fff;border:1px solid #d7e5f6;border-radius:999px;padding:5px 11px;font-size:.79rem;color:#31557d}.decision{position:relative;z-index:1;display:inline-flex;border-radius:10px;padding:10px 14px;margin-top:17px;font-size:.78rem;font-weight:850;letter-spacing:.04em;background:#fff4f5;color:#982f3d;border:1px solid #efc2c8;border-left:5px solid var(--bad)}nav{position:sticky;top:0;z-index:5;background:#ffffffed;backdrop-filter:blur(12px);border-bottom:1px solid var(--line);padding:10px 0;overflow:auto;white-space:nowrap}.nav-inner{width:min(1132px,calc(100% - 48px));margin:0 auto;padding:0 30px}nav a{color:#23466d;text-decoration:none;font-weight:750;margin-right:20px;font-size:13px}main{width:min(1132px,calc(100% - 48px));margin:0 auto;padding:34px 0 70px}section{background:var(--paper);border:1px solid var(--line);border-radius:18px;padding:30px;margin:0 0 24px;box-shadow:0 12px 34px #163b6410}h2{font-size:29px;margin:0 0 8px;letter-spacing:-.025em}h3{margin:23px 0 8px;color:#163d6b}.lede{color:var(--muted);font-size:16px;max-width:960px}.chapter{display:flex;gap:12px;align-items:center;color:#075cae;text-transform:uppercase;letter-spacing:.1em;font-size:12px;font-weight:900;margin-bottom:8px}.chapter b{display:grid;place-items:center;width:28px;height:28px;border-radius:50%;background:#075cae;color:white}.kpis{display:grid;grid-template-columns:repeat(4,1fr);gap:14px;margin-top:24px}.kpi{border-radius:14px;padding:18px;background:linear-gradient(145deg,#f8fbff,#eaf4ff);border:1px solid #d8eafa}.kpi b{display:block;font-size:29px;line-height:1.05}.kpi span{color:var(--muted);font-size:12px;text-transform:uppercase;letter-spacing:.06em}.grid2{display:grid;grid-template-columns:1fr 1fr;gap:20px}.grid3{display:grid;grid-template-columns:repeat(3,1fr);gap:16px}.card{border:1px solid var(--line);border-radius:14px;padding:20px;background:#fbfdff}.callout{border-left:4px solid var(--blue);background:var(--ice);padding:16px 18px;border-radius:4px 12px 12px 4px;margin:18px 0}.callout.red{border-color:var(--bad);background:#fff4f5}.callout.amber{border-color:var(--amber);background:#fff9ec}.table-wrap{overflow:auto;border:1px solid var(--line);border-radius:12px}table{width:100%;border-collapse:collapse;font-size:13px}th{background:#edf5fd;color:#27496f;text-align:left;padding:11px;white-space:nowrap}td{padding:10px 11px;border-top:1px solid var(--line);vertical-align:top}tr:hover td{background:#f7fbff}.figure-wrap{margin:22px 0;border:1px solid var(--line);border-radius:15px;padding:16px;background:#fff;overflow:hidden}.figure-wrap img{display:block;width:100%;height:auto}.figure-caption{margin:9px 4px 0;color:var(--muted);font-size:12px}.formula{font:17px/1.5 Cambria Math,Georgia,serif;text-align:center;background:#f6faff;border:1px solid #dbe8f6;border-radius:11px;padding:13px 16px;margin:15px 0;color:#123d73;overflow:auto}.pill{display:inline-block;border-radius:999px;padding:5px 9px;background:#eaf4ff;color:#075cae;font-weight:700;font-size:12px;margin:3px}.small{font-size:13px;color:var(--muted)}details{border:1px solid var(--line);border-radius:12px;margin-top:18px;background:#fbfdff}summary{cursor:pointer;padding:14px 17px;font-weight:800;color:#174d86}details>*:not(summary){margin-left:17px;margin-right:17px}code{background:#eff4f8;padding:2px 5px;border-radius:5px}footer{color:#708198;text-align:center;padding:20px}@media(max-width:850px){header.qinvia-cover,main{width:calc(100% - 32px)}header.qinvia-cover{margin:16px auto 0;border-radius:14px;padding:32px 24px 38px}.nav-inner{width:calc(100% - 32px);padding:0 24px}section{padding:24px}.kpis,.grid2,.grid3{grid-template-columns:1fr 1fr}}@media(max-width:560px){header.qinvia-cover,main{width:calc(100% - 20px)}.kpis,.grid2,.grid3{grid-template-columns:1fr}section{padding:20px}}@media print{nav{display:none}body{background:white}header.qinvia-cover,main{width:100%}header.qinvia-cover{margin:0;box-shadow:none}section{box-shadow:none;break-inside:avoid}}
# </style><div class="qinvia-cover"><a href="https://qinvia.com" target="_blank"><img src="../assets/qinvia-logo-horizontal.svg" class="qinvia-logo" alt="Qinvia"></a><div class="qinvia-eyebrow">NOTEBOOK NARRATIVO · UNIVERSO ETF</div><h1>Universo ETF · Exposición, habilidad y el listón de SPY</h1><p class="qinvia-subtitle">Quién presenta una trayectoria superior, por qué y qué queda cuando igualamos retorno y cobramos la financiación.</p><div class="qinvia-meta"><span>Estudio 1A</span><span>Corte 01/03/2022</span><span>Datos hasta 04/09/2026</span><span>2.005 productos</span><span>2026-09-09 20:55 UTC</span></div></div>

# %% [markdown]
# Este notebook es la edición pública, narrativa y autocontenida del estudio. Los cálculos se ejecutan en los módulos del proyecto y los datos derivados congelados se incluyen en `artifacts/etf-universe/`; la última celda comprueba las cifras principales.

# %% [markdown]
# ## 1. Tesis ejecutiva
#
# Las métricas tradicionales se conservan como radiografía. Para decidir quién presenta una trayectoria superior a SPY usamos **RWM como criterio principal** y **CAGR como contexto económico**: **156 de 2.005 (7,8%)** superan el RWM de SPY y **89 (4,4%)** superan además su CAGR. De los ganadores RWM, **80** responden a exposición beta identificable y **25** a gestión intencional.
#
# **Qué mide RWM.** Relative-Wealth Martin calcula el ratio de Martin íntegramente sobre la riqueza del ETF relativa a cash. Relaciona el crecimiento anualizado de esa ventaja con el Ulcer Index de la misma curva: premia ganar terreno frente a cash y penaliza la profundidad y persistencia con que se pierde. Aquí lo usamos para condensar crecimiento y daño relativo en una sola lectura. [Más información sobre RWM en Qinvia Research](https://qinvia.com/es/research/relative-wealth-martin).
#
# | Criterio | Baten a SPY | No baten | % del universo |
# |---|---|---|---|
# | CAGR | 204 | 1801 | 0.1017 |
# | Sortino | 195 | 1810 | 0.0973 |
# | Calmar | 238 | 1767 | 0.1187 |
# | Martin | 214 | 1791 | 0.1067 |
# | RWM | 156 | 1849 | 0.0778 |
# | CAGR + RWM | 89 | 1916 | 0.0444 |
# | Las cuatro a la vez | 58 | 1947 | 0.0289 |

# %% [markdown]
# ## 2. Universo y listón de comparación
#
# <img src="../assets/figures/etf-universe/es/universe-funnel.png" style="width:100%">
#
# - Yahoo Adj Close como proxy de rentabilidad total.
# - SPY alineado a las sesiones exactas de cada ETF.
# - CAGR, Sortino, Calmar, Martin y RWM se conservan en las tablas descriptivas.
# - Las conclusiones frente a SPY usan **Relative-Wealth Martin (RWM)**; CAGR queda como segunda coordenada.
# - Cash: FRED DFF, acumulación diaria sin spread, Actual/360.
# - Primera sesión Yahoo ≤ 01/03/2022 y al menos 1.008 retornos.
# - SPY es el coste de oportunidad del inversor, no el benchmark natural de todas las clases.
# - **Survivorship bias material:** 1.938 productos actuales y solo 67 no actuales; no representan una muestra histórica de fondos muertos.
#
# <img src="../assets/figures/etf-universe/es/inception-distribution.png" style="width:100%">

# %% [markdown]
# ## 3. Exposición no es habilidad
#
# <img src="../assets/figures/etf-universe/es/evidence-buckets.png" style="width:100%">
#
# Un sector, tema, país, metal o regla sistemática puede ser una exposición excelente. Que gane ex post demuestra que ese riesgo fue premiado durante la ventana; no demuestra por sí solo selección, timing o control de riesgo del gestor.

# %% [markdown]
# ## 4. Gestión activa y dinámica
#
# El núcleo contiene **204** productos con gestión activa identificada; se añaden **13** alternativas dinámicas no confirmadas como activas. De los **217** del bloque ampliado, **25** superan RWM y **13** superan RWM + CAGR. La intención de gestionar se identifica; la habilidad no se presume.
#
# <img src="../assets/figures/etf-universe/es/management-scorecard.png" style="width:100%">
#
# <img src="../assets/figures/etf-universe/es/management-base-rates.png" style="width:100%">
#
# | Ticker | Producto | Estrategia | CAGR | SPY CAGR | RWM | SPY RWM | Supera CAGR |
# |---|---|---|---|---|---|---|---|
# | FFLC | Fidelity Fundamental Large Cap Core ETF | Factores / estilo | 0.1961 | 0.1674 | 3.4208 | 1.5593 | True |
# | PVAL | Putnam Focused Large Cap Value ETF | Factores / estilo | 0.1684 | 0.1374 | 2.5724 | 1.0632 | True |
# | CLSE | Convergence Long/Short Equity ETF | Long/short y market neutral | 0.2031 | 0.1529 | 2.6347 | 1.2887 | True |
# | CGDV | Capital Group Dividend Value ETF | Dividendos / rentas | 0.1874 | 0.1539 | 2.2516 | 1.2980 | True |
# | FLV | American Century Focused Large Cap Value ETF | Factores / estilo | 0.1612 | 0.2063 | 2.7847 | 2.0408 | False |
# | AVLV | Avantis U.S. Large Cap Value ETF | Factores / estilo | 0.1495 | 0.1328 | 1.6984 | 0.9568 | True |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | Long/short y market neutral | 0.1139 | 0.1818 | 2.4285 | 1.7371 | False |
# | DFIV | Dimensional International Value ETF | Factores / estilo | 0.1636 | 0.1310 | 1.6261 | 0.9437 | True |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | Dividendos / rentas | 0.1288 | 0.1523 | 2.2281 | 1.5676 | False |
# | PWRD | TCW Transform Systems ETF | Renta variable · otra | 0.1933 | 0.1413 | 1.7915 | 1.1602 | True |
# | DARP | Grizzle Growth ETF | Factores / estilo | 0.2041 | 0.1301 | 1.4202 | 0.8861 | True |
# | MBOX | Freedom Day Dividend ETF | Dividendos / rentas | 0.1264 | 0.1376 | 1.5098 | 1.0748 | False |
# | TEQI | T. Rowe Price Equity Income ETF | Dividendos / rentas | 0.1532 | 0.1640 | 1.9095 | 1.4919 | False |
# | JAVA | JPMorgan Active Value ETF | Factores / estilo | 0.1240 | 0.1391 | 1.3727 | 1.0146 | False |
# | FBCV | Fidelity Blue Chip Value ETF | Factores / estilo | 0.1424 | 0.1674 | 1.8457 | 1.5593 | False |
# | HEQT | Simplify Hedged Equity ETF | Long/short y market neutral | 0.0936 | 0.1264 | 1.0749 | 0.8716 | False |
# | AVIV | Avantis International Large Cap Value ETF | Factores / estilo | 0.1441 | 0.1408 | 1.1886 | 1.0344 | True |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | Factores / estilo | 0.1307 | 0.1536 | 1.7405 | 1.6010 | False |
# | DUHP | Dimensional US High Profitability ETF | Renta variable · otra | 0.1389 | 0.1539 | 1.4170 | 1.2980 | False |
# | CGUS | Capital Group Core Equity ETF | Renta variable · otra | 0.1546 | 0.1539 | 1.3938 | 1.2980 | True |
# | TSPA | T. Rowe Price U.S. Equity Research ETF | Renta variable · otra | 0.1414 | 0.1357 | 1.1010 | 1.0361 | True |
# | AVUS | Avantis U.S. Equity ETF | Renta variable · otra | 0.1636 | 0.1634 | 1.5270 | 1.4706 | True |
# | THRO | iShares U.S. Thematic Rotation Active ETF | Temática | 0.1347 | 0.1274 | 0.8786 | 0.8605 | True |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | Dividendos / rentas | 0.1356 | 0.1541 | 1.6310 | 1.6137 | False |
# | DFAU | Dimensional US Core Equity Market ETF | Renta variable · otra | 0.1541 | 0.1571 | 1.3705 | 1.3687 | False |

# %% [markdown]
# ## 5. Candidatos de eficiencia relativa
#
# Hay **12** productos del bloque activo/dinámico que superan RWM pero no CAGR: **11** activos identificados y **1** dinámicos inferidos. Son los candidatos a apalancamiento moderado.
#
# | Ticker | Producto | Clase | Estrategia | Proceso identificado | CAGR | SPY CAGR | RWM | SPY RWM |
# |---|---|---|---|---|---|---|---|---|
# | FLV | American Century Focused Large Cap Value ETF | Renta variable | Factores / estilo | Activa identificada | 0.1612 | 0.2063 | 2.7847 | 2.0408 |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | Alternativas | Long/short y market neutral | Activa identificada | 0.1139 | 0.1818 | 2.4285 | 1.7371 |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | Renta variable | Dividendos / rentas | Activa identificada | 0.1288 | 0.1523 | 2.2281 | 1.5676 |
# | MBOX | Freedom Day Dividend ETF | Renta variable | Dividendos / rentas | Activa identificada | 0.1264 | 0.1376 | 1.5098 | 1.0748 |
# | TEQI | T. Rowe Price Equity Income ETF | Renta variable | Dividendos / rentas | Activa identificada | 0.1532 | 0.1640 | 1.9095 | 1.4919 |
# | JAVA | JPMorgan Active Value ETF | Renta variable | Factores / estilo | Activa identificada | 0.1240 | 0.1391 | 1.3727 | 1.0146 |
# | FBCV | Fidelity Blue Chip Value ETF | Renta variable | Factores / estilo | Activa identificada | 0.1424 | 0.1674 | 1.8457 | 1.5593 |
# | HEQT | Simplify Hedged Equity ETF | Alternativas | Long/short y market neutral | Gestión no indexada identificada | 0.0936 | 0.1264 | 1.0749 | 0.8716 |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | Renta variable | Factores / estilo | Activa identificada | 0.1307 | 0.1536 | 1.7405 | 1.6010 |
# | DUHP | Dimensional US High Profitability ETF | Renta variable | Renta variable · otra | Activa identificada | 0.1389 | 0.1539 | 1.4170 | 1.2980 |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | Renta variable | Dividendos / rentas | Activa identificada | 0.1356 | 0.1541 | 1.6310 | 1.6137 |
# | DFAU | Dimensional US Core Equity Market ETF | Renta variable | Renta variable · otra | Activa identificada | 0.1541 | 0.1571 | 1.3705 | 1.3687 |

# %% [markdown]
# ## 6. Escalera de apalancamiento
#
# Se fija una deuda al inicio y no se rebalancea. La financiación acumula el Effective Federal Funds Rate diario + 1,50%, con Actual/360. No hay rotación ficticia.
#
# <img src="../assets/figures/etf-universe/es/leverage-grid.png" style="width:100%">
#
# | Apalancamiento inicial | Candidatos | Baten CAGR | Conservan RWM | Baten ambos |
# |---|---|---|---|---|
# | 1.0000 | 12 | 0 | 12 | 0 |
# | 1.2500 | 12 | 4 | 10 | 3 |
# | 1.5000 | 12 | 9 | 9 | 6 |
# | 1.7500 | 12 | 10 | 8 | 7 |
# | 2.0000 | 12 | 11 | 8 | 7 |

# %% [markdown]
# ## 7. Retorno igualado y coste de financiación
#
# **11** candidatos alcanzan el capital final de SPY con ≤ 2× y **8** conservan un RWM superior después de financiar la deuda. La solución es ex post y diagnóstica, no una regla ejecutable.
#
# ### Caminos distintos hacia el mismo capital final
#
# <img src="../assets/figures/etf-universe/es/return-matched-equity.png" style="width:100%">
#
# <img src="../assets/figures/etf-universe/es/return-matching-sensitivity.png" style="width:100%">
#
# | Ticker | Producto | Estrategia | Proceso identificado | Apalancamiento requerido | RWM igualado | SPY RWM | Resultado |
# |---|---|---|---|---|---|---|---|
# | DFAU | Dimensional US Core Equity Market ETF | Renta variable · otra | Activa identificada | 1.0365 | 1.3649 | 1.3687 | Iguala; pierde RWM |
# | TEQI | T. Rowe Price Equity Income ETF | Dividendos / rentas | Activa identificada | 1.1313 | 1.9003 | 1.4919 | Iguala y conserva RWM |
# | MBOX | Freedom Day Dividend ETF | Dividendos / rentas | Activa identificada | 1.1759 | 1.4494 | 1.0748 | Iguala y conserva RWM |
# | DUHP | Dimensional US High Profitability ETF | Renta variable · otra | Activa identificada | 1.2162 | 1.3531 | 1.2980 | Iguala y conserva RWM |
# | JAVA | JPMorgan Active Value ETF | Factores / estilo | Activa identificada | 1.2527 | 1.2967 | 1.0146 | Iguala y conserva RWM |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | Dividendos / rentas | Activa identificada | 1.2995 | 1.5986 | 1.6137 | Iguala; pierde RWM |
# | FBCV | Fidelity Blue Chip Value ETF | Factores / estilo | Activa identificada | 1.3443 | 1.7897 | 1.5593 | Iguala y conserva RWM |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | Factores / estilo | Activa identificada | 1.3895 | 1.7412 | 1.6010 | Iguala y conserva RWM |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | Dividendos / rentas | Activa identificada | 1.4081 | 2.1648 | 1.5676 | Iguala y conserva RWM |
# | FLV | American Century Focused Large Cap Value ETF | Factores / estilo | Activa identificada | 1.5662 | 2.8214 | 2.0408 | Iguala y conserva RWM |
# | HEQT | Simplify Hedged Equity ETF | Long/short y market neutral | Gestión no indexada identificada | 1.9735 | 0.8334 | 0.8716 | Iguala; pierde RWM |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | Long/short y market neutral | Activa identificada | 2.3863 | 2.3000 | 1.7371 | Exige más de 2× |
#
# ### Sensibilidad al margen de financiación
#
# | Margen sobre Fed Funds | Alcanzables ≤ 2× | Conservan RWM |
# |---|---|---|
# | 0.0100 | 11 | 10 |
# | 0.0150 | 11 | 8 |
# | 0.0200 | 10 | 8 |
# | 0.0250 | 10 | 8 |

# %% [markdown]
# ## 8. Estabilidad al punto de entrada
#
# De los 25 ganadores RWM del bloque gestionado, **12** superan el RWM de SPY desde la mayoría de los meses de entrada. Las ventanas de tres años se solapan: es una sensibilidad temporal, no una prueba independiente de persistencia.
#
# <img src="../assets/figures/etf-universe/es/entry-point-robustness.png" style="width:100%">
#
# | Ticker | Producto | Supera RWM | % CAGR | % RWM | % CAGR + RWM | Peor Δ CAGR | Peor Δ RWM |
# |---|---|---|---|---|---|---|---|
# | CGUS | Capital Group Core Equity ETF | 19/19 | 0.8947 | 1.0000 | 0.8947 | -0.0018 | 0.0474 |
# | CGDV | Capital Group Dividend Value ETF | 19/19 | 1.0000 | 1.0000 | 1.0000 | 0.0189 | 0.6705 |
# | TSPA | T. Rowe Price U.S. Equity Research ETF | 26/27 | 1.0000 | 0.9630 | 0.9630 | 0.0029 | -0.0711 |
# | CLSE | Convergence Long/Short Equity ETF | 16/19 | 0.8421 | 0.8421 | 0.7895 | -0.0050 | -0.3672 |
# | PVAL | Putnam Focused Large Cap Value ETF | 23/28 | 0.7500 | 0.8214 | 0.7500 | -0.0320 | -0.7786 |
# | FFLC | Fidelity Fundamental Large Cap Core ETF | 31/39 | 0.9744 | 0.7949 | 0.7949 | -0.0031 | -0.3524 |
# | DFIV | Dimensional International Value ETF | 17/24 | 0.6250 | 0.7083 | 0.6250 | -0.0511 | -0.4833 |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | 53/81 | 0.0741 | 0.6543 | 0.0741 | -0.0919 | -1.8021 |
# | PWRD | TCW Transform Systems ETF | 12/19 | 1.0000 | 0.6316 | 0.6316 | 0.0134 | -0.8739 |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | 24/40 | 0.1000 | 0.6000 | 0.1000 | -0.1377 | -3.1295 |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | 43/82 | 0.2073 | 0.5244 | 0.2073 | -0.0926 | -2.0670 |
# | THRO | iShares U.S. Thematic Rotation Active ETF | 11/21 | 0.9048 | 0.5238 | 0.5238 | -0.0061 | -0.5544 |
# | HEQT | Simplify Hedged Equity ETF | 10/22 | 0.0455 | 0.4545 | 0.0455 | -0.0904 | -1.0031 |
# | FLV | American Century Focused Large Cap Value ETF | 18/41 | 0.0732 | 0.4390 | 0.0732 | -0.1222 | -3.1059 |
# | AVUS | Avantis U.S. Equity ETF | 21/48 | 0.3750 | 0.4375 | 0.3333 | -0.0366 | -1.4939 |
# | MBOX | Freedom Day Dividend ETF | 12/28 | 0.3571 | 0.4286 | 0.3571 | -0.0960 | -2.7316 |
# | AVIV | Avantis International Large Cap Value ETF | 9/23 | 0.3043 | 0.3913 | 0.3043 | -0.0642 | -0.6465 |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | 32/83 | 0.2771 | 0.3855 | 0.2771 | -0.0629 | -2.0553 |
# | TEQI | T. Rowe Price Equity Income ETF | 13/37 | 0.1351 | 0.3514 | 0.1351 | -0.1174 | -3.1864 |
# | AVLV | Avantis U.S. Large Cap Value ETF | 7/24 | 0.2500 | 0.2917 | 0.0833 | -0.0714 | -2.4065 |
# | DUHP | Dimensional US High Profitability ETF | 5/19 | 0.1053 | 0.2632 | 0.1053 | -0.0487 | -1.1950 |
# | FBCV | Fidelity Blue Chip Value ETF | 9/39 | 0.1282 | 0.2308 | 0.1282 | -0.1340 | -3.5516 |
# | JAVA | JPMorgan Active Value ETF | 4/23 | 0.0435 | 0.1739 | 0.0435 | -0.1003 | -2.8832 |
# | DARP | Grizzle Growth ETF | 1/21 | 0.7619 | 0.0476 | 0.0476 | -0.0516 | -1.5857 |
# | DFAU | Dimensional US Core Equity Market ETF | 0/34 | 0.0000 | 0.0000 | 0.0000 | -0.0136 | -0.7965 |

# %% [markdown]
# ## 9. Síntesis RWM y contraste DBF
#
# <img src="../assets/figures/etf-universe/es/rwm-cagr-scatter.png" style="width:100%">
#
# RWM decide la comparación con SPY; CAGR mantiene visible la magnitud económica. **156 (7,8%)** productos superan RWM y **89 (4,4%)** superan RWM + CAGR. DBF± permanece como descriptor de dirección y breadth; no decide ganadores.
#
# ### Mayores ventajas RWM
#
# | Ticker | Producto | Proceso | CAGR | SPY CAGR | RWM | SPY RWM | Δ RWM | Supera CAGR |
# |---|---|---|---|---|---|---|---|---|
# | FFLC | Fidelity Fundamental Large Cap Core ETF | Activa identificada | 0.1961 | 0.1674 | 3.4208 | 1.5593 | 1.8615 | True |
# | PSMJ | Pacer Swan SOS Moderate (July) ETF | Gestión no indexada identificada | 0.1052 | 0.1321 | 2.6214 | 0.9886 | 1.6328 | False |
# | BALT | Innovator Defined Wealth Shield ETF | Gestión no indexada identificada | 0.0602 | 0.1336 | 2.5859 | 1.0057 | 1.5801 | False |
# | PVAL | Putnam Focused Large Cap Value ETF | Activa identificada | 0.1684 | 0.1374 | 2.5724 | 1.0632 | 1.5092 | True |
# | PSMO | Pacer Swan SOS Moderate (October) ETF | Gestión no indexada identificada | 0.1044 | 0.1414 | 2.4887 | 1.0388 | 1.4499 | False |
# | PSFO | Pacer Swan SOS Flex (October) ETF | Gestión no indexada identificada | 0.1170 | 0.1382 | 2.3863 | 1.0069 | 1.3794 | False |
# | RISR | FolioBeyond Alternative Income and Interest Rate Hedge ETF | Gestión no indexada identificada | 0.1387 | 0.1382 | 2.3828 | 1.0069 | 1.3759 | True |
# | PSFJ | Pacer Swan SOS Flex (July) ETF | Gestión no indexada identificada | 0.1138 | 0.1336 | 2.3703 | 1.0057 | 1.3646 | False |
# | CLSE | Convergence Long/Short Equity ETF | Activa identificada | 0.2031 | 0.1529 | 2.6347 | 1.2887 | 1.3460 | True |
# | PSFD | Pacer Swan SOS Flex (January) ETF | Gestión no indexada identificada | 0.1281 | 0.1535 | 2.3402 | 1.3121 | 1.0280 | False |
# | CGDV | Capital Group Dividend Value ETF | Activa identificada | 0.1874 | 0.1539 | 2.2516 | 1.2980 | 0.9536 | True |
# | NETZ | Engine No. 1 Transform Climate ETF | Gestión no indexada identificada | 0.2006 | 0.1306 | 1.9087 | 1.0187 | 0.8899 | True |
# | PSFF | Pacer Swan SOS Fund of Funds ETF | Gestión no indexada identificada | 0.1011 | 0.1517 | 2.0817 | 1.2885 | 0.7932 | False |
# | BOAT | SonicShares Global Shipping ETF | Índice/pasiva identificada | 0.2825 | 0.1319 | 1.7417 | 0.9709 | 0.7708 | True |
# | FLV | American Century Focused Large Cap Value ETF | Activa identificada | 0.1612 | 0.2063 | 2.7847 | 2.0408 | 0.7439 | False |
#
# ### Mayores perfiles DBF±
#
# | Ticker | Producto | CAGR | DBF± | D± | J |
# |---|---|---|---|---|---|
# | SGOV | iShares 0-3 Month Treasury Bond ETF | 0.0294 | 0.3829 | 0.8599 | 0.4453 |
# | BILS | State Street SPDR Bloomberg 3-12 Month T-Bill ETF | 0.0289 | 0.3253 | 0.7483 | 0.4347 |
# | BKUI | BNY Mellon Ultra Short Income ETF | 0.0348 | 0.2493 | 0.4649 | 0.5362 |
# | VUSB | Vanguard Ultra-Short Bond ETF | 0.0330 | 0.1725 | 0.3334 | 0.5174 |
# | TBUX | T. Rowe Price Ultra Short-Term Bond ETF | 0.0404 | 0.1656 | 0.3155 | 0.5250 |
# | SHV | iShares 0-1 Year Treasury Bond ETF | 0.0159 | 0.1642 | 0.4411 | 0.3722 |
# | GBIL | Goldman Sachs Access Treasury 0-1 Year ETF | 0.0229 | 0.1478 | 0.5660 | 0.2612 |
# | GSST | Goldman Sachs Ultra Short Bond ETF | 0.0324 | 0.1383 | 0.3766 | 0.3673 |
# | CLTL | Invesco Treasury Collateral ETF | 0.0241 | 0.1278 | 0.5403 | 0.2364 |
# | TBLL | Invesco Short Term Treasury ETF | 0.0241 | 0.1238 | 0.5433 | 0.2279 |

# %% [markdown]
# ## 10. Curva común desde el corte
#
# <img src="../assets/figures/etf-universe/es/universe-fan.png" style="width:100%">
#
# El abanico muestra los percentiles 10–90 y 25–75 de 1.935 productos con cobertura completa.
#
# <img src="../assets/figures/etf-universe/es/common-period-curve.png" style="width:100%">
#
# Media y mediana transversal de capital buy-and-hold. Es una descripción del universo, no una cartera rebalanceada ni una estrategia operable.

# %% [markdown]
# ## 11. Veredicto Qinvia
#
# - Solo 7,8% del universo supera el RWM de SPY.
# - Solo 4,4% supera RWM + CAGR.
# - La mayoría de ganadores atribuibles refleja beta, no gestión demostrada.
# - 25 de 217 productos con gestión intencional superan RWM; 12 lo hacen desde la mayoría de puntos de entrada.
# - Al igualar retorno y cobrar financiación, 8 de 11 casos alcanzables conservan RWM.
#
# ### Capacidad, escala y paradoja del éxito
#
# **Hipótesis compatible con la literatura, no hallazgo causal.** Una explicación posible es que el alfa tenga capacidad finita: los buenos resultados atraen activos gestionados y desplegar posiciones mayores sobre un conjunto limitado de oportunidades puede elevar el impacto de mercado, los costes, las restricciones de liquidez y la competencia. [Berk y Green (2004)](https://doi.org/10.1086/424739) formalizan este equilibrio; [Chen et al. (2004)](https://doi.org/10.1257/0002828043052277) encuentran una relación más adversa en fondos expuestos a acciones pequeñas e ilíquidas, y [Pástor, Stambaugh y Taylor](https://www.nber.org/system/files/working_papers/w19891/w19891.pdf) hallan evidencia fuerte de rendimientos decrecientes a escala de la industria, pero menos concluyente al nivel de cada fondo.
#
# El contrapunto importa: con operaciones institucionales reales, [Frazzini, Israel y Moskowitz](https://pages.stern.nyu.edu/~afrazzin/pdf/Trading%20Cost%20of%20Asset%20Pricing%20Anomalies%20-%20Frazzini%2C%20Israel%20and%20Moskowitz.pdf) estiman una capacidad muy superior a la supuesta previamente para ciertas estrategias y muestran que una ejecución diseñada para reducir costes puede ampliarla sustancialmente. La capacidad depende del turnover, el horizonte, la liquidez, la amplitud del mercado y la ejecución. Nuestros datos ETF no identifican causalmente el efecto de los flujos ni estiman la capacidad de cada proceso; presentamos el mecanismo como explicación plausible, no como conclusión demostrada.
#
# **Conclusión:** SPY constituye un listón estructuralmente alto: diversificación, ponderación por capitalización, renovación de componentes, liquidez y bajo coste. La industria ofrece miles de narrativas y exposiciones; la evidencia de valor añadido por gestión es mucho más escasa. Complejidad, marca y activos gestionados no sustituyen a la prueba empírica.

# %% [markdown]
# ## 12. Límites y fuentes
#
# - SPY no es el benchmark natural de todos los mandatos.
# - El estilo de gestión está asignado en todas las filas mediante SEC N-CEN y fuentes primarias documentadas; otras dimensiones taxonómicas pueden conservar una clase desconocida explícita.
# - El apalancamiento exacto se resuelve ex post.
# - El 25% de mantenimiento es ilustrativo.
# - La cohorte Yahoo no contiene una muestra representativa de ETF muertos; el survivorship bias sigue siendo material.
# - La siguiente prueba causal requiere un benchmark pasivo comparable por exposición para cada gestor.
#
# Fuentes de financiación: [IBKR Margin Rates](https://www.interactivebrokers.com/en/trading/margin-rates.php), [IBKR Margin Calculation](https://www.interactivebrokers.com/en/trading/margin-calculation-details.php) y [FRED DFF](https://fred.stlouisfed.org/series/DFF).
#
# La carpeta `artifacts/etf-universe/` contiene la cohorte, la auditoría de gestión, taxonomía, resultados de apalancamiento, sensibilidad y robustez.

# %% [markdown]
# ## 13. Comprobación reproducible
#
# Esta celda opcional carga los datos congelados incluidos junto al notebook y verifica las magnitudes principales.

# %%
from pathlib import Path
import pandas as pd

repo_root = Path.cwd()
if not (repo_root / "artifacts" / "etf-universe").exists():
    repo_root = repo_root.parent
data_dir = repo_root / "artifacts" / "etf-universe"
selected_check = pd.read_parquet(data_dir / "selected_etfs.parquet")
managed_check = pd.read_csv(data_dir / "intentional_management_products.csv")
matched_check = pd.read_csv(data_dir / "return_matched_leverage.csv")
curves_check = pd.read_parquet(data_dir / "return_matched_equity_curves.parquet")

{
    "productos": len(selected_check),
    "superan_rwm_spy": int(selected_check.beat_spy_rwm_score.sum()),
    "superan_rwm_y_cagr": int(selected_check.beat_spy_cagr_and_rwm.sum()),
    "gestion_intencional_supera_rwm": int(managed_check.beat_spy_rwm_score.sum()),
    "igualan_spy_hasta_2x": int(matched_check.feasible_at_or_below_2x.sum()),
    "igualan_y_conservan_rwm": int((matched_check.feasible_at_or_below_2x & matched_check.matched_rwm_beats_spy.fillna(False)).sum()),
    "curvas_retorno_igualado": int(curves_check.request_symbol.nunique()),
}
# Out:
# {'productos': 2005,
#  'superan_rwm_spy': 156,
#  'superan_rwm_y_cagr': 89,
#  'gestion_intencional_supera_rwm': 25,
#  'igualan_spy_hasta_2x': 11,
#  'igualan_y_conservan_rwm': 8,
#  'curvas_retorno_igualado': 11}

# %% [markdown]
# ---
#
# **Qinvia · Carlos Barredo Lago**
