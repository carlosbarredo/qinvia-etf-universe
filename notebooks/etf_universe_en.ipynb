# %% [markdown]
# <style>
# :root{--navy:#08296b;--blue:#0868d7;--cyan:#0bb9df;--ice:#eef7ff;--ink:#10213d;--muted:#62728a;--line:#dce8f4;--good:#0a9b71;--bad:#d84b5b;--amber:#d89014;--paper:#fff;color-scheme:light only}
# *{box-sizing:border-box}html{scroll-behavior:smooth}body{margin:0;font:15px/1.58 Inter,Segoe UI,Arial,sans-serif;color:var(--ink);background:#f3f7fb}header.qinvia-cover{width:min(1132px,calc(100% - 48px));margin:28px auto 0;padding:42px 30px 46px;background:linear-gradient(120deg,#f8fbff 0%,#eef6ff 55%,#e7faff 100%);border:1px solid #e3eaf3;border-radius:18px;box-shadow:0 18px 50px rgba(8,41,107,.09);position:relative;overflow:hidden}.qinvia-cover:after{content:'';position:absolute;right:-80px;bottom:-130px;width:360px;height:360px;border-radius:50%;background:radial-gradient(circle,rgba(11,185,223,.18),rgba(8,104,215,0) 68%);pointer-events:none}.qinvia-cover>a{display:inline-block;position:relative;z-index:1}.qinvia-logo{display:block;width:min(590px,78%);height:auto;margin:0 0 30px}.qinvia-eyebrow{position:relative;z-index:1;font-weight:800;letter-spacing:.16em;color:#0b72c9;font-size:.78rem}.qinvia-cover h1{position:relative;z-index:1;font-size:clamp(38px,5vw,58px);line-height:1.06;margin:.6rem 0 .7rem;color:var(--navy);max-width:980px;letter-spacing:-.035em}.qinvia-subtitle{position:relative;z-index:1;font-size:1.18rem;color:#3b587d;margin:0 0 1.4rem;max-width:980px}.qinvia-meta{position:relative;z-index:1;display:flex;gap:9px;flex-wrap:wrap}.qinvia-meta span{background:#fff;border:1px solid #d7e5f6;border-radius:999px;padding:5px 11px;font-size:.79rem;color:#31557d}.decision{position:relative;z-index:1;display:inline-flex;border-radius:10px;padding:10px 14px;margin-top:17px;font-size:.78rem;font-weight:850;letter-spacing:.04em;background:#fff4f5;color:#982f3d;border:1px solid #efc2c8;border-left:5px solid var(--bad)}nav{position:sticky;top:0;z-index:5;background:#ffffffed;backdrop-filter:blur(12px);border-bottom:1px solid var(--line);padding:10px 0;overflow:auto;white-space:nowrap}.nav-inner{width:min(1132px,calc(100% - 48px));margin:0 auto;padding:0 30px}nav a{color:#23466d;text-decoration:none;font-weight:750;margin-right:20px;font-size:13px}main{width:min(1132px,calc(100% - 48px));margin:0 auto;padding:34px 0 70px}section{background:var(--paper);border:1px solid var(--line);border-radius:18px;padding:30px;margin:0 0 24px;box-shadow:0 12px 34px #163b6410}h2{font-size:29px;margin:0 0 8px;letter-spacing:-.025em}h3{margin:23px 0 8px;color:#163d6b}.lede{color:var(--muted);font-size:16px;max-width:960px}.chapter{display:flex;gap:12px;align-items:center;color:#075cae;text-transform:uppercase;letter-spacing:.1em;font-size:12px;font-weight:900;margin-bottom:8px}.chapter b{display:grid;place-items:center;width:28px;height:28px;border-radius:50%;background:#075cae;color:white}.kpis{display:grid;grid-template-columns:repeat(4,1fr);gap:14px;margin-top:24px}.kpi{border-radius:14px;padding:18px;background:linear-gradient(145deg,#f8fbff,#eaf4ff);border:1px solid #d8eafa}.kpi b{display:block;font-size:29px;line-height:1.05}.kpi span{color:var(--muted);font-size:12px;text-transform:uppercase;letter-spacing:.06em}.grid2{display:grid;grid-template-columns:1fr 1fr;gap:20px}.grid3{display:grid;grid-template-columns:repeat(3,1fr);gap:16px}.card{border:1px solid var(--line);border-radius:14px;padding:20px;background:#fbfdff}.callout{border-left:4px solid var(--blue);background:var(--ice);padding:16px 18px;border-radius:4px 12px 12px 4px;margin:18px 0}.callout.red{border-color:var(--bad);background:#fff4f5}.callout.amber{border-color:var(--amber);background:#fff9ec}.table-wrap{overflow:auto;border:1px solid var(--line);border-radius:12px}table{width:100%;border-collapse:collapse;font-size:13px}th{background:#edf5fd;color:#27496f;text-align:left;padding:11px;white-space:nowrap}td{padding:10px 11px;border-top:1px solid var(--line);vertical-align:top}tr:hover td{background:#f7fbff}.figure-wrap{margin:22px 0;border:1px solid var(--line);border-radius:15px;padding:16px;background:#fff;overflow:hidden}.figure-wrap img{display:block;width:100%;height:auto}.figure-caption{margin:9px 4px 0;color:var(--muted);font-size:12px}.formula{font:17px/1.5 Cambria Math,Georgia,serif;text-align:center;background:#f6faff;border:1px solid #dbe8f6;border-radius:11px;padding:13px 16px;margin:15px 0;color:#123d73;overflow:auto}.pill{display:inline-block;border-radius:999px;padding:5px 9px;background:#eaf4ff;color:#075cae;font-weight:700;font-size:12px;margin:3px}.small{font-size:13px;color:var(--muted)}details{border:1px solid var(--line);border-radius:12px;margin-top:18px;background:#fbfdff}summary{cursor:pointer;padding:14px 17px;font-weight:800;color:#174d86}details>*:not(summary){margin-left:17px;margin-right:17px}code{background:#eff4f8;padding:2px 5px;border-radius:5px}footer{color:#708198;text-align:center;padding:20px}@media(max-width:850px){header.qinvia-cover,main{width:calc(100% - 32px)}header.qinvia-cover{margin:16px auto 0;border-radius:14px;padding:32px 24px 38px}.nav-inner{width:calc(100% - 32px);padding:0 24px}section{padding:24px}.kpis,.grid2,.grid3{grid-template-columns:1fr 1fr}}@media(max-width:560px){header.qinvia-cover,main{width:calc(100% - 20px)}.kpis,.grid2,.grid3{grid-template-columns:1fr}section{padding:20px}}@media print{nav{display:none}body{background:white}header.qinvia-cover,main{width:100%}header.qinvia-cover{margin:0;box-shadow:none}section{box-shadow:none;break-inside:avoid}}
# </style><div class="qinvia-cover"><a href="https://qinvia.com" target="_blank"><img src="../assets/qinvia-logo-horizontal.svg" class="qinvia-logo" alt="Qinvia"></a><div class="qinvia-eyebrow">NARRATIVE NOTEBOOK · ETF UNIVERSE</div><h1>ETF Universe · Exposure, Skill, and Why SPY Is So Hard to Beat</h1><p class="qinvia-subtitle">Who produced a superior path, why—and what remains after return matching and financing.</p><div class="qinvia-meta"><span>Study 1A</span><span>Cutoff 1 Mar 2022</span><span>Data through 04 Sep 2026</span><span>2,005 products</span><span>2026-09-09 20:55 UTC</span></div></div>

# %% [markdown]
# This notebook is the public, narrative, self-contained edition of the study. Project modules perform the calculations and frozen derived datasets are included in `artifacts/etf-universe/`; the final cell verifies the headline counts.

# %% [markdown]
# ## 1. Executive thesis
#
# Traditional metrics remain as a diagnostic. To decide which products produced a superior path to SPY, we use **RWM as the primary criterion** and **CAGR as economic context**: **156 of 2,005 (7.8%)** beat SPY's RWM and **89 (4.4%)** also beat its CAGR. Of the RWM winners, **80** reflect identifiable beta exposure and **25** involve intentional management.
#
# **What RWM measures.** Relative-Wealth Martin calculates the Martin ratio entirely on ETF wealth relative to cash. It relates the annualised growth of that advantage to the Ulcer Index of the same curve: gaining ground versus cash is rewarded, while the depth and persistence of losing it are penalised. Here it condenses relative growth and damage into a single reading. [Read more about RWM at Qinvia Research](https://qinvia.com/research/relative-wealth-martin).
#
# | Criterion | Beat SPY | Do not beat SPY | % of universe |
# |---|---|---|---|
# | CAGR | 204 | 1801 | 0.1017 |
# | Sortino | 195 | 1810 | 0.0973 |
# | Calmar | 238 | 1767 | 0.1187 |
# | Martin | 214 | 1791 | 0.1067 |
# | RWM | 156 | 1849 | 0.0778 |
# | CAGR + RWM | 89 | 1916 | 0.0444 |
# | All four at once | 58 | 1947 | 0.0289 |

# %% [markdown]
# ## 2. Universe and comparison bar
#
# <img src="../assets/figures/etf-universe/en/universe-funnel.png" style="width:100%">
#
# - Yahoo Adj Close is used as a total-return proxy.
# - SPY is aligned to the exact sessions of each ETF.
# - CAGR, Sortino, Calmar, Martin and RWM remain in the descriptive tables.
# - Conclusions versus SPY use **Relative-Wealth Martin (RWM)**; CAGR is the second coordinate.
# - Cash: FRED DFF, daily accrual without spread, Actual/360.
# - First Yahoo session ≤ 1 Mar 2022 and at least 1,008 returns.
# - SPY is the investor's opportunity cost, not the natural benchmark for every asset class.
# - **Material survivorship bias:** 1,938 current products and only 67 non-current products; they are not a representative history of dead funds.
#
# <img src="../assets/figures/etf-universe/en/inception-distribution.png" style="width:100%">

# %% [markdown]
# ## 3. Exposure is not skill
#
# <img src="../assets/figures/etf-universe/en/evidence-buckets.png" style="width:100%">
#
# A sector, theme, country, metal or systematic rule may be an excellent exposure. Winning ex post shows that the risk was rewarded during the sample; it does not by itself demonstrate manager selection, timing or risk control.

# %% [markdown]
# ## 4. Active and dynamic management
#
# The core contains **204** products with identified active management, plus **13** dynamic alternatives not confirmed as active. Of the **217** products in the extended block, **25** beat RWM and **13** beat RWM + CAGR. Intent to manage is identified; skill is not presumed.
#
# <img src="../assets/figures/etf-universe/en/management-scorecard.png" style="width:100%">
#
# <img src="../assets/figures/etf-universe/en/management-base-rates.png" style="width:100%">
#
# | Ticker | Product | Strategy | CAGR | SPY CAGR | RWM | SPY RWM | Beats CAGR |
# |---|---|---|---|---|---|---|---|
# | FFLC | Fidelity Fundamental Large Cap Core ETF | Factor / style | 0.1961 | 0.1674 | 3.4208 | 1.5593 | True |
# | PVAL | Putnam Focused Large Cap Value ETF | Factor / style | 0.1684 | 0.1374 | 2.5724 | 1.0632 | True |
# | CLSE | Convergence Long/Short Equity ETF | Long/short and market neutral | 0.2031 | 0.1529 | 2.6347 | 1.2887 | True |
# | CGDV | Capital Group Dividend Value ETF | Dividend / income | 0.1874 | 0.1539 | 2.2516 | 1.2980 | True |
# | FLV | American Century Focused Large Cap Value ETF | Factor / style | 0.1612 | 0.2063 | 2.7847 | 2.0408 | False |
# | AVLV | Avantis U.S. Large Cap Value ETF | Factor / style | 0.1495 | 0.1328 | 1.6984 | 0.9568 | True |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | Long/short and market neutral | 0.1139 | 0.1818 | 2.4285 | 1.7371 | False |
# | DFIV | Dimensional International Value ETF | Factor / style | 0.1636 | 0.1310 | 1.6261 | 0.9437 | True |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | Dividend / income | 0.1288 | 0.1523 | 2.2281 | 1.5676 | False |
# | PWRD | TCW Transform Systems ETF | Equity · other | 0.1933 | 0.1413 | 1.7915 | 1.1602 | True |
# | DARP | Grizzle Growth ETF | Factor / style | 0.2041 | 0.1301 | 1.4202 | 0.8861 | True |
# | MBOX | Freedom Day Dividend ETF | Dividend / income | 0.1264 | 0.1376 | 1.5098 | 1.0748 | False |
# | TEQI | T. Rowe Price Equity Income ETF | Dividend / income | 0.1532 | 0.1640 | 1.9095 | 1.4919 | False |
# | JAVA | JPMorgan Active Value ETF | Factor / style | 0.1240 | 0.1391 | 1.3727 | 1.0146 | False |
# | FBCV | Fidelity Blue Chip Value ETF | Factor / style | 0.1424 | 0.1674 | 1.8457 | 1.5593 | False |
# | HEQT | Simplify Hedged Equity ETF | Long/short and market neutral | 0.0936 | 0.1264 | 1.0749 | 0.8716 | False |
# | AVIV | Avantis International Large Cap Value ETF | Factor / style | 0.1441 | 0.1408 | 1.1886 | 1.0344 | True |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | Factor / style | 0.1307 | 0.1536 | 1.7405 | 1.6010 | False |
# | DUHP | Dimensional US High Profitability ETF | Equity · other | 0.1389 | 0.1539 | 1.4170 | 1.2980 | False |
# | CGUS | Capital Group Core Equity ETF | Equity · other | 0.1546 | 0.1539 | 1.3938 | 1.2980 | True |
# | TSPA | T. Rowe Price U.S. Equity Research ETF | Equity · other | 0.1414 | 0.1357 | 1.1010 | 1.0361 | True |
# | AVUS | Avantis U.S. Equity ETF | Equity · other | 0.1636 | 0.1634 | 1.5270 | 1.4706 | True |
# | THRO | iShares U.S. Thematic Rotation Active ETF | Thematic equity | 0.1347 | 0.1274 | 0.8786 | 0.8605 | True |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | Dividend / income | 0.1356 | 0.1541 | 1.6310 | 1.6137 | False |
# | DFAU | Dimensional US Core Equity Market ETF | Equity · other | 0.1541 | 0.1571 | 1.3705 | 1.3687 | False |

# %% [markdown]
# ## 5. Relative-efficiency candidates
#
# There are **12** products in the active/dynamic block that beat RWM but not CAGR: **11** identified active products and **1** inferred dynamic strategies. These are the candidates for moderate leverage.
#
# | Ticker | Product | Asset class | Strategy | Identified process | CAGR | SPY CAGR | RWM | SPY RWM |
# |---|---|---|---|---|---|---|---|---|
# | FLV | American Century Focused Large Cap Value ETF | Equity | Factor / style | Identified active | 0.1612 | 0.2063 | 2.7847 | 2.0408 |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | Alternatives | Long/short and market neutral | Identified active | 0.1139 | 0.1818 | 2.4285 | 1.7371 |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | Equity | Dividend / income | Identified active | 0.1288 | 0.1523 | 2.2281 | 1.5676 |
# | MBOX | Freedom Day Dividend ETF | Equity | Dividend / income | Identified active | 0.1264 | 0.1376 | 1.5098 | 1.0748 |
# | TEQI | T. Rowe Price Equity Income ETF | Equity | Dividend / income | Identified active | 0.1532 | 0.1640 | 1.9095 | 1.4919 |
# | JAVA | JPMorgan Active Value ETF | Equity | Factor / style | Identified active | 0.1240 | 0.1391 | 1.3727 | 1.0146 |
# | FBCV | Fidelity Blue Chip Value ETF | Equity | Factor / style | Identified active | 0.1424 | 0.1674 | 1.8457 | 1.5593 |
# | HEQT | Simplify Hedged Equity ETF | Alternatives | Long/short and market neutral | Identified non-index management | 0.0936 | 0.1264 | 1.0749 | 0.8716 |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | Equity | Factor / style | Identified active | 0.1307 | 0.1536 | 1.7405 | 1.6010 |
# | DUHP | Dimensional US High Profitability ETF | Equity | Equity · other | Identified active | 0.1389 | 0.1539 | 1.4170 | 1.2980 |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | Equity | Dividend / income | Identified active | 0.1356 | 0.1541 | 1.6310 | 1.6137 |
# | DFAU | Dimensional US Core Equity Market ETF | Equity | Equity · other | Identified active | 0.1541 | 0.1571 | 1.3705 | 1.3687 |

# %% [markdown]
# ## 6. Leverage ladder
#
# Debt is fixed at inception and the position is not rebalanced. Financing accrues the daily Effective Federal Funds Rate + 1.50% under Actual/360. No fictional turnover is introduced.
#
# <img src="../assets/figures/etf-universe/en/leverage-grid.png" style="width:100%">
#
# | Initial leverage | Candidates | Beat CAGR | Preserve RWM | Beat both |
# |---|---|---|---|---|
# | 1.0000 | 12 | 0 | 12 | 0 |
# | 1.2500 | 12 | 4 | 10 | 3 |
# | 1.5000 | 12 | 9 | 9 | 6 |
# | 1.7500 | 12 | 10 | 8 | 7 |
# | 2.0000 | 12 | 11 | 8 | 7 |

# %% [markdown]
# ## 7. Return matching and financing cost
#
# **11** candidates reach SPY's terminal wealth at ≤ 2× and **8** preserve a higher RWM after financing. The solution is ex post and diagnostic, not an executable rule.
#
# ### Different paths to the same terminal wealth
#
# <img src="../assets/figures/etf-universe/en/return-matched-equity.png" style="width:100%">
#
# <img src="../assets/figures/etf-universe/en/return-matching-sensitivity.png" style="width:100%">
#
# | Ticker | Product | Strategy | Identified process | Required leverage | Matched RWM | SPY RWM | Outcome |
# |---|---|---|---|---|---|---|---|
# | DFAU | Dimensional US Core Equity Market ETF | Equity · other | Identified active | 1.0365 | 1.3649 | 1.3687 | Matches; loses RWM |
# | TEQI | T. Rowe Price Equity Income ETF | Dividend / income | Identified active | 1.1313 | 1.9003 | 1.4919 | Matches and preserves RWM |
# | MBOX | Freedom Day Dividend ETF | Dividend / income | Identified active | 1.1759 | 1.4494 | 1.0748 | Matches and preserves RWM |
# | DUHP | Dimensional US High Profitability ETF | Equity · other | Identified active | 1.2162 | 1.3531 | 1.2980 | Matches and preserves RWM |
# | JAVA | JPMorgan Active Value ETF | Factor / style | Identified active | 1.2527 | 1.2967 | 1.0146 | Matches and preserves RWM |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | Dividend / income | Identified active | 1.2995 | 1.5986 | 1.6137 | Matches; loses RWM |
# | FBCV | Fidelity Blue Chip Value ETF | Factor / style | Identified active | 1.3443 | 1.7897 | 1.5593 | Matches and preserves RWM |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | Factor / style | Identified active | 1.3895 | 1.7412 | 1.6010 | Matches and preserves RWM |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | Dividend / income | Identified active | 1.4081 | 2.1648 | 1.5676 | Matches and preserves RWM |
# | FLV | American Century Focused Large Cap Value ETF | Factor / style | Identified active | 1.5662 | 2.8214 | 2.0408 | Matches and preserves RWM |
# | HEQT | Simplify Hedged Equity ETF | Long/short and market neutral | Identified non-index management | 1.9735 | 0.8334 | 0.8716 | Matches; loses RWM |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | Long/short and market neutral | Identified active | 2.3863 | 2.3000 | 1.7371 | Requires more than 2× |
#
# ### Financing-spread sensitivity
#
# | Spread over Fed Funds | Feasible at ≤ 2× | Preserve RWM |
# |---|---|---|
# | 0.0100 | 11 | 10 |
# | 0.0150 | 11 | 8 |
# | 0.0200 | 10 | 8 |
# | 0.0250 | 10 | 8 |

# %% [markdown]
# ## 8. Entry-point stability
#
# Of the 25 RWM winners in the managed block, **12** beat SPY's RWM from a majority of entry months. The three-year windows overlap: this is temporal sensitivity, not an independent test of persistence.
#
# <img src="../assets/figures/etf-universe/en/entry-point-robustness.png" style="width:100%">
#
# | Ticker | Product | Beats RWM | % CAGR | % RWM | % CAGR + RWM | Worst Δ CAGR | Worst Δ RWM |
# |---|---|---|---|---|---|---|---|
# | CGUS | Capital Group Core Equity ETF | 19/19 | 0.8947 | 1.0000 | 0.8947 | -0.0018 | 0.0474 |
# | CGDV | Capital Group Dividend Value ETF | 19/19 | 1.0000 | 1.0000 | 1.0000 | 0.0189 | 0.6705 |
# | TSPA | T. Rowe Price U.S. Equity Research ETF | 26/27 | 1.0000 | 0.9630 | 0.9630 | 0.0029 | -0.0711 |
# | CLSE | Convergence Long/Short Equity ETF | 16/19 | 0.8421 | 0.8421 | 0.7895 | -0.0050 | -0.3672 |
# | PVAL | Putnam Focused Large Cap Value ETF | 23/28 | 0.7500 | 0.8214 | 0.7500 | -0.0320 | -0.7786 |
# | FFLC | Fidelity Fundamental Large Cap Core ETF | 31/39 | 0.9744 | 0.7949 | 0.7949 | -0.0031 | -0.3524 |
# | DFIV | Dimensional International Value ETF | 17/24 | 0.6250 | 0.7083 | 0.6250 | -0.0511 | -0.4833 |
# | DIVO | Amplify CWP Enhanced Dividend Income ETF | 53/81 | 0.0741 | 0.6543 | 0.0741 | -0.0919 | -1.8021 |
# | PWRD | TCW Transform Systems ETF | 12/19 | 1.0000 | 0.6316 | 0.6316 | 0.0134 | -0.8739 |
# | SIXH | ETC 6 Meridian Hedged Equity Index Option ETF | 24/40 | 0.1000 | 0.6000 | 0.1000 | -0.1377 | -3.1295 |
# | FLLV | Franklin Liberty U.S. Low Volatility ETF | 43/82 | 0.2073 | 0.5244 | 0.2073 | -0.0926 | -2.0670 |
# | THRO | iShares U.S. Thematic Rotation Active ETF | 11/21 | 0.9048 | 0.5238 | 0.5238 | -0.0061 | -0.5544 |
# | HEQT | Simplify Hedged Equity ETF | 10/22 | 0.0455 | 0.4545 | 0.0455 | -0.0904 | -1.0031 |
# | FLV | American Century Focused Large Cap Value ETF | 18/41 | 0.0732 | 0.4390 | 0.0732 | -0.1222 | -3.1059 |
# | AVUS | Avantis U.S. Equity ETF | 21/48 | 0.3750 | 0.4375 | 0.3333 | -0.0366 | -1.4939 |
# | MBOX | Freedom Day Dividend ETF | 12/28 | 0.3571 | 0.4286 | 0.3571 | -0.0960 | -2.7316 |
# | AVIV | Avantis International Large Cap Value ETF | 9/23 | 0.3043 | 0.3913 | 0.3043 | -0.0642 | -0.6465 |
# | RFDA | ALPS Dynamic US Dividend Advantage ETF | 32/83 | 0.2771 | 0.3855 | 0.2771 | -0.0629 | -2.0553 |
# | TEQI | T. Rowe Price Equity Income ETF | 13/37 | 0.1351 | 0.3514 | 0.1351 | -0.1174 | -3.1864 |
# | AVLV | Avantis U.S. Large Cap Value ETF | 7/24 | 0.2500 | 0.2917 | 0.0833 | -0.0714 | -2.4065 |
# | DUHP | Dimensional US High Profitability ETF | 5/19 | 0.1053 | 0.2632 | 0.1053 | -0.0487 | -1.1950 |
# | FBCV | Fidelity Blue Chip Value ETF | 9/39 | 0.1282 | 0.2308 | 0.1282 | -0.1340 | -3.5516 |
# | JAVA | JPMorgan Active Value ETF | 4/23 | 0.0435 | 0.1739 | 0.0435 | -0.1003 | -2.8832 |
# | DARP | Grizzle Growth ETF | 1/21 | 0.7619 | 0.0476 | 0.0476 | -0.0516 | -1.5857 |
# | DFAU | Dimensional US Core Equity Market ETF | 0/34 | 0.0000 | 0.0000 | 0.0000 | -0.0136 | -0.7965 |

# %% [markdown]
# ## 9. RWM synthesis and DBF contrast
#
# <img src="../assets/figures/etf-universe/en/rwm-cagr-scatter.png" style="width:100%">
#
# RWM decides the comparison with SPY; CAGR keeps economic magnitude visible. **156 (7.8%)** products beat RWM and **89 (4.4%)** beat RWM + CAGR. DBF± remains a direction-and-breadth descriptor; it does not select winners.
#
# ### Largest RWM advantages
#
# | Ticker | Product | Process | CAGR | SPY CAGR | RWM | SPY RWM | Δ RWM | Beats CAGR |
# |---|---|---|---|---|---|---|---|---|
# | FFLC | Fidelity Fundamental Large Cap Core ETF | Identified active | 0.1961 | 0.1674 | 3.4208 | 1.5593 | 1.8615 | True |
# | PSMJ | Pacer Swan SOS Moderate (July) ETF | Identified non-index management | 0.1052 | 0.1321 | 2.6214 | 0.9886 | 1.6328 | False |
# | BALT | Innovator Defined Wealth Shield ETF | Identified non-index management | 0.0602 | 0.1336 | 2.5859 | 1.0057 | 1.5801 | False |
# | PVAL | Putnam Focused Large Cap Value ETF | Identified active | 0.1684 | 0.1374 | 2.5724 | 1.0632 | 1.5092 | True |
# | PSMO | Pacer Swan SOS Moderate (October) ETF | Identified non-index management | 0.1044 | 0.1414 | 2.4887 | 1.0388 | 1.4499 | False |
# | PSFO | Pacer Swan SOS Flex (October) ETF | Identified non-index management | 0.1170 | 0.1382 | 2.3863 | 1.0069 | 1.3794 | False |
# | RISR | FolioBeyond Alternative Income and Interest Rate Hedge ETF | Identified non-index management | 0.1387 | 0.1382 | 2.3828 | 1.0069 | 1.3759 | True |
# | PSFJ | Pacer Swan SOS Flex (July) ETF | Identified non-index management | 0.1138 | 0.1336 | 2.3703 | 1.0057 | 1.3646 | False |
# | CLSE | Convergence Long/Short Equity ETF | Identified active | 0.2031 | 0.1529 | 2.6347 | 1.2887 | 1.3460 | True |
# | PSFD | Pacer Swan SOS Flex (January) ETF | Identified non-index management | 0.1281 | 0.1535 | 2.3402 | 1.3121 | 1.0280 | False |
# | CGDV | Capital Group Dividend Value ETF | Identified active | 0.1874 | 0.1539 | 2.2516 | 1.2980 | 0.9536 | True |
# | NETZ | Engine No. 1 Transform Climate ETF | Identified non-index management | 0.2006 | 0.1306 | 1.9087 | 1.0187 | 0.8899 | True |
# | PSFF | Pacer Swan SOS Fund of Funds ETF | Identified non-index management | 0.1011 | 0.1517 | 2.0817 | 1.2885 | 0.7932 | False |
# | BOAT | SonicShares Global Shipping ETF | Identified index/passive | 0.2825 | 0.1319 | 1.7417 | 0.9709 | 0.7708 | True |
# | FLV | American Century Focused Large Cap Value ETF | Identified active | 0.1612 | 0.2063 | 2.7847 | 2.0408 | 0.7439 | False |
#
# ### Highest DBF± profiles
#
# | Ticker | Product | CAGR | DBF± | D± | J |
# |---|---|---|---|---|---|
# | SGOV | iShares 0-3 Month Treasury Bond ETF | 0.0294 | 0.3829 | 0.8599 | 0.4453 |
# | BILS | State Street SPDR Bloomberg 3-12 Month T-Bill ETF | 0.0289 | 0.3253 | 0.7483 | 0.4347 |
# | BKUI | BNY Mellon Ultra Short Income ETF | 0.0348 | 0.2493 | 0.4649 | 0.5362 |
# | VUSB | Vanguard Ultra-Short Bond ETF | 0.0330 | 0.1725 | 0.3334 | 0.5174 |
# | TBUX | T. Rowe Price Ultra Short-Term Bond ETF | 0.0404 | 0.1656 | 0.3155 | 0.5250 |
# | SHV | iShares 0-1 Year Treasury Bond ETF | 0.0159 | 0.1642 | 0.4411 | 0.3722 |
# | GBIL | Goldman Sachs Access Treasury 0-1 Year ETF | 0.0229 | 0.1478 | 0.5660 | 0.2612 |
# | GSST | Goldman Sachs Ultra Short Bond ETF | 0.0324 | 0.1383 | 0.3766 | 0.3673 |
# | CLTL | Invesco Treasury Collateral ETF | 0.0241 | 0.1278 | 0.5403 | 0.2364 |
# | TBLL | Invesco Short Term Treasury ETF | 0.0241 | 0.1238 | 0.5433 | 0.2279 |

# %% [markdown]
# ## 10. Common curve from the cutoff
#
# <img src="../assets/figures/etf-universe/en/universe-fan.png" style="width:100%">
#
# The fan displays the 10th–90th and 25th–75th percentiles for 1,935 products with complete coverage.
#
# <img src="../assets/figures/etf-universe/en/common-period-curve.png" style="width:100%">
#
# Cross-sectional mean and median buy-and-hold wealth. This describes the universe; it is neither a rebalanced portfolio nor a tradable strategy.

# %% [markdown]
# ## 11. Qinvia verdict
#
# - Only 7.8% of the universe beats SPY's RWM.
# - Only 4.4% beats RWM + CAGR.
# - Most attributable winners reflect beta, not demonstrated management skill.
# - 25 of 217 intentional-management products beat RWM; 12 do so from a majority of entry points.
# - After return matching and financing, 8 of 11 feasible cases preserve RWM.
#
# ### Capacity, scale and the success paradox
#
# **A literature-consistent hypothesis, not a causal finding.** One possible explanation is that alpha has finite capacity: strong results attract assets under management, and deploying larger positions across a limited opportunity set can increase market impact, costs, liquidity constraints and competition. [Berk and Green (2004)](https://doi.org/10.1086/424739) formalise this equilibrium; [Chen et al. (2004)](https://doi.org/10.1257/0002828043052277) find a more adverse size relationship among funds exposed to small and illiquid stocks, while [Pástor, Stambaugh and Taylor](https://www.nber.org/system/files/working_papers/w19891/w19891.pdf) find strong decreasing returns at the industry level but less conclusive evidence at the individual-fund level.
#
# The counterpoint matters. Using real institutional trades, [Frazzini, Israel and Moskowitz](https://pages.stern.nyu.edu/~afrazzin/pdf/Trading%20Cost%20of%20Asset%20Pricing%20Anomalies%20-%20Frazzini%2C%20Israel%20and%20Moskowitz.pdf) estimate far greater capacity than previously assumed for some strategies and show that cost-aware execution can expand it substantially. Capacity depends on turnover, horizon, liquidity, market breadth and execution. Our ETF data do not causally identify the effect of flows or estimate the capacity of each process; this mechanism is presented as a plausible explanation, not a demonstrated conclusion.
#
# **Conclusion:** SPY sets a structurally high bar through diversification, capitalisation weighting, constituent renewal, liquidity and low cost. The industry offers thousands of narratives and exposures; evidence of management-added value is far scarcer. Complexity, brand and assets under management do not replace empirical proof.

# %% [markdown]
# ## 12. Limits and sources
#
# - SPY is not the natural benchmark for every mandate.
# - Management style is assigned on every row using SEC N-CEN and documented primary-source evidence; other taxonomy dimensions can still retain an explicit unknown class.
# - Exact leverage is solved ex post.
# - The 25% maintenance threshold is illustrative.
# - The Yahoo cohort does not contain a representative history of dead ETFs; survivorship bias remains material.
# - A causal follow-up requires an exposure-matched passive benchmark for every manager.
#
# Financing sources: [IBKR Margin Rates](https://www.interactivebrokers.com/en/trading/margin-rates.php), [IBKR Margin Calculation](https://www.interactivebrokers.com/en/trading/margin-calculation-details.php) and [FRED DFF](https://fred.stlouisfed.org/series/DFF).
#
# The `artifacts/etf-universe/` directory contains the cohort, management audit, taxonomy, leverage, sensitivity and robustness outputs.

# %% [markdown]
# ## 13. Reproducibility check
#
# This optional cell loads the frozen datasets distributed alongside the notebook and verifies the headline counts.

# %%
from pathlib import Path
import pandas as pd

repo_root = Path.cwd()
if not (repo_root / "artifacts" / "etf-universe").exists():
    repo_root = repo_root.parent
data_dir = repo_root / "artifacts" / "etf-universe"
selected_check = pd.read_parquet(data_dir / "selected_etfs.parquet")
managed_check = pd.read_csv(data_dir / "intentional_management_products.csv")
matched_check = pd.read_csv(data_dir / "return_matched_leverage.csv")
curves_check = pd.read_parquet(data_dir / "return_matched_equity_curves.parquet")

{
    "products": len(selected_check),
    "beat_spy_rwm": int(selected_check.beat_spy_rwm_score.sum()),
    "beat_spy_rwm_and_cagr": int(selected_check.beat_spy_cagr_and_rwm.sum()),
    "intentional_management_beats_rwm": int(managed_check.beat_spy_rwm_score.sum()),
    "match_spy_at_or_below_2x": int(matched_check.feasible_at_or_below_2x.sum()),
    "match_and_preserve_rwm": int((matched_check.feasible_at_or_below_2x & matched_check.matched_rwm_beats_spy.fillna(False)).sum()),
    "return_matched_curves": int(curves_check.request_symbol.nunique()),
}
# Out:
# {'products': 2005,
#  'beat_spy_rwm': 156,
#  'beat_spy_rwm_and_cagr': 89,
#  'intentional_management_beats_rwm': 25,
#  'match_spy_at_or_below_2x': 11,
#  'match_and_preserve_rwm': 8,
#  'return_matched_curves': 11}

# %% [markdown]
# ---
#
# **Qinvia · Carlos Barredo Lago**
